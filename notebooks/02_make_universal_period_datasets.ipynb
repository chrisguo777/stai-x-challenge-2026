# %%
import pandas as pd

from statx_helpers import save_all_datasets

# Universal dataset: all scored overdose categories together.
df = pd.read_csv("../outputs/train_universal_merged.csv")

summary, train_periods, val_periods = save_all_datasets(
    df,
    output_dir="../outputs",
    prefix="universal",
    val_size=0.2,
    random_state=42,
)

print("Original data shape:", df.shape)
print("Train periods:", len(train_periods), "| Validation periods:", len(val_periods))
display(summary)
print("Period-split datasets saved successfully.")
